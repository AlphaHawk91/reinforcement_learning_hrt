# %%
import pandas as pd

df = pd.read_csv('./intraday_data_preprocessed.csv')

# %%
df.head()
# Out:
#                     Datetime  Close_HDFCBANK.NS  Close_SBIN.NS  Close_TCS.NS  \
# 0  2025-04-01 03:45:00+00:00           0.680494       0.753802      0.988329
# 1  2025-04-01 03:46:00+00:00           0.678518       0.744297      0.992154
# 2  2025-04-01 03:47:00+00:00           0.661234       0.784220      0.974303
# 3  2025-04-01 03:48:00+00:00           0.655308       0.776616      0.955669
# 4  2025-04-01 03:49:00+00:00           0.644444       0.770913      0.938211
#
#    High_HDFCBANK.NS  High_SBIN.NS  High_TCS.NS  Low_HDFCBANK.NS  Low_SBIN.NS  \
# 0          0.685012      0.746884     1.000000         0.670967     0.623092
# 1          0.668795      0.744967     0.987786         0.667991     0.732825
# 2          0.668305      0.791946     0.986862         0.661539     0.762404
# 3          0.663391      0.778524     0.968182         0.657568     0.791030
# 4          0.639311      0.775647     0.954428         0.640695     0.785305
#
# ...
